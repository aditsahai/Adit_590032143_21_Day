# %% [markdown]
# #Conditional Statements

# %%
age =21
if age>=18:
    print("valid for voting")
# Out:
# valid for voting

# %%
number=7
if number%2==0:
    print("the number is even")
else:
    print("the number is odd")
# Out:
# the number is odd

# %%
score=82
if score>=92:
    print("A Grade")
elif score>=75 and score<92:
    print("B Grade")
else:
    print("C Grade")
# Out:
# B Grade

# %%
temp=32
if temp>=35:
    print("hot")
elif temp>=20 and temp<35:
    print("comfortable")
else:
    print("cold")
# Out:
# comfortable

# %%
username='admin'
password='python123'

print(username=="admin" and password=="python123")
# Out:
# True

# %%
value=15
print(value>10 or value<10)
print(not value==20)
# Out:
# True
# True

# %%
balance =500
withdrawal =300
if withdrawal <= balance:
    print("transaction approved")
else:
    print("insufficient balance")
# Out:
# transaction approved

# %%
day ="saturday"
print('weekend' if day in ["saturday","sunday"] else "weekday")
# Out:
# weekend

# %%
item=[]
if item:
    print("cart has items ")
else:
    print("cart is empty")
# Out:
# cart is empty

# %%
age =25
has_id=True 
if age>=18 and has_id:
    print("entry allowed ")
# Out:
# entry allowed
