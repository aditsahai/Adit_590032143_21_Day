# %% [markdown]
# #Numbers and Operators

# %%
print(10+3,10-3,10*3)
# Out:
# 13 7 30

# %%
print(10/3)
print(10//3)
print(10%3)
# Out:
# 3.3333333333333335
# 3
# 1

# %%
print(2**5)
# Out:
# 32

# %%
marks=[78,91,84,67]
print(sum(marks),max(marks),min(marks))
# Out:
# 320 91 67

# %%
temprature_c=30
print((temprature_c*9/5)+32)
# Out:
# 86.0

# %%
principal= 10000
rate = 0.08
years = 2
print(principal*(1+rate)**years)
# Out:
# 11664.000000000002

# %%
amount=1250
gst= amount*0.18
print(amount+gst)
# Out:
# 1475.0

# %%
number=17
print(number%2==0)
# Out:
# False

# %%
import math
print(math.sqrt(144))
print(math.ceil(4.2),math.floor(4.8))
# Out:
# 12.0
# 5 4

# %%
score =[72,88,91]
average=sum(score)/len(score)
print(round(average,1))
# Out:
# 83.7
