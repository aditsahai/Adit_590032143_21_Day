# %% [markdown]
# #Python Day 1 Basic

# %%
age=25
city="dehradun"

print(age,city)
# Out:
# 25 dehradun

# %%
name ="adit sahai"
print(name)
# Out:
# adit sahai

# %%
a=10
b=10.0
c="10"
d=True

print(type(a),type(b),type(c),type(d))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>

# %%
price=499.99
print(type(price))
# Out:
# <class 'float'>

# %%
x=10
print(x)

x=20
print(x)
# Out:
# 10
# 20

# %%
student_name="Rahul"
print(student_name)
# Out:
# Rahul

# %%
student_name="abd"
2student="ghi"
student2="jik"
student-name="jhj"
_score="he8"
# Out:
#   Cell In[8], line 2
#     2student="ghi"
#     ^
# SyntaxError: invalid decimal literal

# %%
a=5
b=3

print(a+b)
print(a*b)
# Out:
# 8
# 15

# %%
lenght=10
width=5

area=lenght*width
print("the area of the rectange is:",area)
# Out:
# the area of the rectange is: 50

# %%
x="10"
y="20"

print(x+y)
# Out:
# 1020

# %%
number="25"
a=int(number)

print(a+5)
# Out:
# 30

# %%
x=10
y=float(x)

print(y)
print(type(y))
# Out:
# 10.0
# <class 'float'>

# %%
price=99.5

a=int(price)
print(a)
print(type(a))
# Out:
# 99
# <class 'int'>

# %%
a=10
b=3

print(a/b)
print(a//b)
print(a%b)
# Out:
# 3.3333333333333335
# 3
# 1

# %%
a,b,c=10,20,30
print(a,b,c)
# Out:
# 10 20 30

# %%
x=5
x=x+10
x=x*2
print(x)
# Out:
# 30

# %%
age="20"
new_age=age+1

print(new_age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 age="20"
# ----> 2 new_age=age+1
#       3
#       4 print(new_age)
#
# TypeError: can only concatenate str (not "int") to str

# %%
name=input("enter name: ")
age=int(input("enter age:"))
course=input("enter course: ")

mark1=int(input("enter mark1: "))
mark2=int(input("enter mark2: "))
mark3=int(input("enter mark3: "))

total_marks=mark1+mark2+mark3

avg_marks=total_marks/3

print("student name is:",name)
print("student age is:",age)
print("student course is:",course)
print("marks of subject 1 is:",mark1)
print("marks of subject 2 is:",mark2)
print("marks of subject 3 is:",mark3)
print("the total marks obtained are:",total_marks)
print("the average marks obtained are: ",avg_marks)
# Out:
# student name is: adit sahai
# student age is: 18
# student course is: computer science
# marks of subject 1 is: 100
# marks of subject 2 is: 90
# marks of subject 3 is: 80
# the total marks obtained are: 270
# the average marks obtained are:  90.0
